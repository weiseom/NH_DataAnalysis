# %%
import urllib.request as req
from bs4 import BeautifulSoup

# %%
url = "https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%ED%99%98%EC%9C%A8"

res = req.urlopen(url)

# 체계적으로 찾을 수 있도록 도와주는 라이브러리 > beautifulsoup

# %%
soup = BeautifulSoup(res, "html.parser")
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
trs = soup.select(".rate_table_info tbody tr")

# tr들이 들어있다.

# %%
for tr in trs:
    name= tr.select_one('em').text
    rate = tr.select_one('span').text
    print(name, rate)
# Out:
# USD 미국 USD
# JPY 100 일본 JPY 100
# EUR 유럽연합 EUR
# CNY 중국 CNY
# GBP 영국 GBP
# AUD 호주 AUD
# CAD 캐나다 CAD
# NZD 뉴질랜드 NZD
